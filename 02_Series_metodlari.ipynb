# %%
import pandas as pd
import numpy as np
from pandas import Series # Series ma'lumotlar tuzilmasi

# %%
cars_dict = {'Malibu':40000, 'Lacetti':20000, 'Toyota':45000, 'Mazda':52000, 'Honda':38000}

# %%
cars1 = Series(cars_dict) # lugatdan series yaratdik

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
models = ['Honda', 'Mazda', 'Lacetti', 'Jaguar', 'Malibu', 'Toyota', 'BMW', 'Mersedes']

# %%
cars2 = Series(cars_dict, index=models)

# %%
cars2
# Out:
# Honda       38000.0
# Mazda       52000.0
# Lacetti     20000.0
# Jaguar          NaN
# Malibu      40000.0
# Toyota      45000.0
# BMW             NaN
# Mersedes        NaN
# dtype: float64

# %%
cars2.isnull() # NaN qiymatlarga borligiga tekshirish
# Out:
# Honda       False
# Mazda       False
# Lacetti     False
# Jaguar       True
# Malibu      False
# Toyota      False
# BMW          True
# Mersedes     True
# dtype: bool

# %%
cars2.notnull()
# Out:
# Honda        True
# Mazda        True
# Lacetti      True
# Jaguar      False
# Malibu       True
# Toyota       True
# BMW         False
# Mersedes    False
# dtype: bool

# %%
cars2
# Out:
# Honda       38000.0
# Mazda       52000.0
# Lacetti     20000.0
# Jaguar          NaN
# Malibu      40000.0
# Toyota      45000.0
# BMW             NaN
# Mersedes        NaN
# dtype: float64

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
cars1 + cars2 # indeks bo'yicha qo'shish
# Out:
# BMW              NaN
# Honda        76000.0
# Jaguar           NaN
# Lacetti      40000.0
# Malibu       80000.0
# Mazda       104000.0
# Mersedes         NaN
# Toyota       90000.0
# dtype: float64

# %%
cars2.name = 'Avtosalon'

# %%
cars2.index.name = 'Modellar'
cars2
# Out:
# Modellar
# Honda       38000.0
# Mazda       52000.0
# Lacetti     20000.0
# Jaguar          NaN
# Malibu      40000.0
# Toyota      45000.0
# BMW             NaN
# Mersedes        NaN
# Name: Avtosalon, dtype: float64

# %% [markdown]
# Series obyektiga oid ba'zi parametrlar va metodlar

# %%
cars2.index
# Out:
# Index(['Honda', 'Mazda', 'Lacetti', 'Jaguar', 'Malibu', 'Toyota', 'BMW',
#        'Mersedes'],
#       dtype='object', name='Modellar')

# %%
cars2.values
# Out:
# array([38000., 52000., 20000.,    nan, 40000., 45000.,    nan,    nan])

# %%
cars2.hasnans # NaN qiymatlar bor/yo'q
# Out:
# True

# %%
cars2.dtype # data type
# Out:
# dtype('float64')

# %%
cars2.is_unique # qiymatlar betakrormi
# Out:
# False

# %%
cars2.shape # Series hajmi
# Out:
# (8,)

# %%
cars2.size
# Out:
# 8

# %%
cars2.iloc[1] # 1-indeks qiymati
# Out:
# 52000.0

# %%
cars2['Honda']
# Out:
# 38000.0

# %%
cars2.loc['Toyota'] # indeksga murojaat
# Out:
# 45000.0

# %%
cars2.max()
# Out:
# 52000.0

# %%
cars2.mean() # o'rta qiymat
# Out:
# 39000.0
