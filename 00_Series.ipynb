# %%
import numpy as np
import pandas as pd

# %%
from pandas import Series # Series ma'lumotlar tuzilmasi

# %%
obj = Series([4, 5, 6, -6.5])

# %%
type(obj)
# Out:
# pandas.core.series.Series

# %%
print(obj)
# Out:
# 0    4.0
# 1    5.0
# 2    6.0
# 3   -6.5
# dtype: float64

# %%
obj.values
# Out:
# array([ 4. ,  5. ,  6. , -6.5])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj[0]
# Out:
# 4.0

# %%
obj2 = Series([6, 3, 2, 1], index=['a','b','c','d'])
obj2
# Out:
# a    6
# b    3
# c    2
# d    1
# dtype: int64

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
obj2['a']
# Out:
# 6

# %%
obj2[['d','c','a']]
# Out:
# d    1
# c    2
# a    6
# dtype: int64

# %%
obj2[['d','d','d']]
# Out:
# d    1
# d    1
# d    1
# dtype: int64

# %%
obj2[obj2>2] # 2 dan katta qiymatlarni filtrlash
# Out:
# a    6
# b    3
# dtype: int64

# %%
obj2[obj2<3]
# Out:
# c    2
# d    1
# dtype: int64

# %%
obj2*2
# Out:
# a    12
# b     6
# c     4
# d     2
# dtype: int64

# %%
np.exp(obj2)
# Out:
# a    403.428793
# b     20.085537
# c      7.389056
# d      2.718282
# dtype: float64
