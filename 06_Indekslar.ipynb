# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
data = {'Yil':[2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
        'Aholi soni':[33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
        'Temp':[1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53],
        'YAIM':[1700, 1670, 1600, 1590, 1400, 1300, 1350, 1360]
}
df = DataFrame(data, index=[21, 20, 19, 18, 17, 16, 15, 10])

# %% [markdown]
# Index obyekti

# %%
df
# Out:
#      Yil  Aholi soni  Temp  YAIM
# 21  2021        33.9  1.54  1700
# 20  2020        33.5  1.48  1670
# 19  2019        32.9  1.56  1600
# 18  2018        32.5  1.62  1590
# 17  2017        31.9  1.65  1400
# 16  2016        31.4  1.66  1300
# 15  2015        30.9  1.64  1350
# 10  2010        28.5  1.53  1360

# %%
df.index # indeks degan obyekt
# Out:
# Int64Index([21, 20, 19, 18, 17, 16, 15, 10], dtype='int64')

# %%
df.columns # bu ham  indeks degan obyekt
# Out:
# Index(['Yil', 'Aholi soni', 'Temp', 'YAIM'], dtype='object')

# %%
indeks = df.columns
indeks
# Out:
# Index(['Yil', 'Aholi soni', 'Temp', 'YAIM'], dtype='object')

# %%
'Temp' in indeks # ustun nomlari orasidan izlash
# Out:
# True

# %%
'Temp' in df.columns # bu ham
# Out:
# True

# %%
2021 in df.index
# Out:
# False

# %%
21 in df.index
# Out:
# True

# %%
indeks[0]
# Out:
# 'Yil'

# %%
indeks[2:4]
# Out:
# Index(['Temp', 'YAIM'], dtype='object')

# %%
df.columns[2:4]
# Out:
# Index(['Temp', 'YAIM'], dtype='object')

# %%
indeks[0] = 'qiymat' # indeks qiymatini o'zgartirsh mumkin emas
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-ae345364899c> in <module>()
# ----> 1 indeks[0] = 'qiymat'
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    4082
#    4083     def __setitem__(self, key, value):
# -> 4084         raise TypeError("Index does not support mutable operations")
#    4085
#    4086     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
data1 = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}
df1 = pd.DataFrame(data1)

# %%
df1
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
'2021' in df1
# Out:
# False

# %%
'2021' in df1.index
# Out:
# False

# %%
2021 in df1.index
# Out:
# True

# %%
Uzbekistan in df1.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-e1d759060c57> in <module>()
# ----> 1 Uzbekistan in df1.columns
#
# NameError: name 'Uzbekistan' is not defined

# %%
'Uzbekistan' in df1.columns
# Out:
# True

# %%
df2 = df1.T
df2
# Out:
#             2021  2020  2019  2018  2017  2016
# Uzbekistan  33.9  33.5  32.9  32.5  31.9   NaN
# Kazakhstan  18.9  18.7  18.5  18.3  18.1  17.8

# %%
'Uzbekistan' in df2.index
# Out:
# True

# %%
df2.index
# Out:
# Index(['Uzbekistan', 'Kazakhstan'], dtype='object')

# %%
df2.columns
# Out:
# Int64Index([2021, 2020, 2019, 2018, 2017, 2016], dtype='int64')

# %%
df3 = pd.DataFrame(df2.values, columns=df2.columns, index=['Uzb', 'Kaz'])
df3
# Out:
#      2021  2020  2019  2018  2017  2016
# Uzb  33.9  33.5  32.9  32.5  31.9   NaN
# Kaz  18.9  18.7  18.5  18.3  18.1  17.8
