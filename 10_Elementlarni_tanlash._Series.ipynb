# %% [markdown]
# # Indekslash, qator(ustun) tanlash, filtrlash

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
data = {'Yil':[2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
        'Aholi soni':[33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
        'Temp':[1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53],
        'Zichlik':[79.77, 78.68, 77.53, 76.34, 75.13, 73.91, 72.71, 67.03]
}
df = pd.DataFrame(data, index=[21, 20, 19, 18, 17, 16, 15, 10])
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 21  2021        33.9  1.54    79.77
# 20  2020        33.5  1.48    78.68
# 19  2019        32.9  1.56    77.53
# 18  2018        32.5  1.62    76.34
# 17  2017        31.9  1.65    75.13
# 16  2016        31.4  1.66    73.91
# 15  2015        30.9  1.64    72.71
# 10  2010        28.5  1.53    67.03

# %%
dataF = df[['Aholi soni']]  # [[]] -- DataFrame dan qism datafreym
dataF

# %%
type(dataF)
# Out:
# pandas.core.frame.DataFrame

# %%
data = df['Aholi soni']  # [] -- Series obyekti
data
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Aholi soni, dtype: float64

# %%
type(data) # Series obyektini qaytaradi
# Out:
# pandas.core.series.Series

# %%
data[21] # numpy qiymat kerak bo'lganda [] qavs ishlating
# Out:
# 33.9

# %%
type(data[21])
# Out:
# numpy.float64

# %%
data[[21]]
# Out:
# 21    33.9
# Name: Aholi soni, dtype: float64

# %%
type(data[[21]]) # Series obyekti zarur bo'lganda [[]] qavslar ishlating
# Out:
# pandas.core.series.Series

# %%
data
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Aholi soni, dtype: float64

# %%
data[0:4]
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# Name: Aholi soni, dtype: float64

# %%
data[[21, 20, 19, 18]]
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# Name: Aholi soni, dtype: float64

# %%
obj = pd.Series(np.arange(8.), index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# f    5.0
# g    6.0
# h    7.0
# dtype: float64

# %%
obj['a']
# Out:
# 0.0

# %%
obj[0:4]
# Out:
# a    15.0
# b    15.0
# c    15.0
# d     3.0
# dtype: float64

# %%
obj[['a']]
# Out:
# a    0.0
# dtype: float64

# %%
obj[0:4]
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj['c':'h']
# Out:
# c    2.0
# d    3.0
# e    4.0
# f    5.0
# g    6.0
# h    7.0
# dtype: float64

# %%
obj['a':'c']=15

# %%
obj
# Out:
# a    15.0
# b    15.0
# c    15.0
# d     3.0
# e     4.0
# f     5.0
# g     6.0
# h     7.0
# dtype: float64

# %%
obj[obj<15] # filtrlash
# Out:
# d    3.0
# e    4.0
# f    5.0
# g    6.0
# h    7.0
# dtype: float64
