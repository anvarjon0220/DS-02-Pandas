# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
usernames = {'anvar':'anvarbek223','olim':'olimtoy','maryam':'mary345','javohir':'javoh445'}
emails = {'anvar':'anvar@gmail.com','olim':'olim@mail.ru','maryam':'mary33@gmail.com','javohir':'javoh445@gmail.com'}

data = {
    'username':usernames,
    'email':emails
}
df = pd.DataFrame(data)

# %%
df
# Out:
#             username               email
# anvar    anvarbek223     anvar@gmail.com
# olim         olimtoy        olim@mail.ru
# maryam       mary345    mary33@gmail.com
# javohir     javoh445  javoh445@gmail.com

# %%
df.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir'], dtype='object')

# %%
arr = ['anvar', 'olim', 'maryam', 'javohir']

# %%
data2 = {
    'username':{'olim':'olimjon21','maryam':'maryam2020'},
    'email':{'olim':'olimjon21@mail.ru','maryam':'maryam20@gmail.com'}
}

# %%
df2 = df.append(pd.DataFrame(data2))

# %%
df2
# Out:
#             username               email
# anvar    anvarbek223     anvar@gmail.com
# olim         olimtoy        olim@mail.ru
# maryam       mary345    mary33@gmail.com
# javohir     javoh445  javoh445@gmail.com
# olim       olimjon21   olimjon21@mail.ru
# maryam    maryam2020  maryam20@gmail.com

# %%
newind = pd.Index(['olim','nafisa','hamida'])
newind
# Out:
# Index(['olim', 'nafisa', 'hamida'], dtype='object')

# %%
newind.isin(df2.index) # newind elementlari df2 indexlari orasida bormi?
# Out:
# array([ True, False, False])

# %%
df2.index.difference(newind) # farqi
# Out:
# Index(['anvar', 'javohir', 'maryam'], dtype='object')

# %%
newind.difference(df2.index) #farqi
# Out:
# Index(['hamida', 'nafisa'], dtype='object')

# %%
df2.index.union(newind) # indekslarni jamlash
# Out:
# Index(['anvar', 'hamida', 'javohir', 'maryam', 'maryam', 'nafisa', 'olim',
#        'olim'],
#       dtype='object')

# %%
df2.index.delete(0)
# Out:
# Index(['olim', 'maryam', 'javohir', 'olim', 'maryam'], dtype='object')

# %%
newind
# Out:
# Index(['olim', 'nafisa', 'hamida'], dtype='object')

# %%
newind.drop('hamida')
# Out:
# Index(['olim', 'nafisa'], dtype='object')
